# %% [markdown]
# ## Bibliotecas Utilizadas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import regex as re
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
from operator import itemgetter

from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import NMF, LatentDirichletAllocation

# %% [markdown]
# # Carregando os dados

# %%
politicos = {}
lista_dir = os.listdir("./politicos/")
nome_politicos = []
for nome in lista_dir:
    politicos[nome[:-4]] = df_amoedo = pd.read_csv(
        f"./politicos/{nome}",
        delimiter=",",
        encoding='utf-8',
        usecols=[1,2,8]
    )
    nome_politicos.append(nome[:-4])

# %%
print(len(nome_politicos))
politicos['Doria'].head()
# Out:
# 11
#              created_at                                               text  \
# 0  2021-04-19T13:04:16Z  São ao todo 41 milhões e 400 mil doses da vaci...
# 1  2021-04-19T13:04:15Z  Estive hoje, às 5h30 da manhã, no Aeroporto de...
# 2  2021-04-19T10:03:50Z  Insumos para mais 5 milhões de doses da Vacina...
# 3  2021-04-19T09:17:48Z  Bom dia, pessoal. Estamos em Guarulhos receben...
# 4  2021-04-19T01:28:03Z  A operação Paz e Proteção impediu a realização...
#
#                     id
# 0  1384130730851135495
# 1  1384130727348867079
# 2  1384085323588665344
# 3  1384073738887438337
# 4  1383955522076827650

# %% [markdown]
# ## Unindo Doria(1), Bolsonaro(2) e Lula(3) em um dataframe

# %%
# stopwords e simbolos a retirar
stop_words = set(['de','a','o','que','e','é','do','da','em','um','para','com','não','uma','os','no','se','na','por','mais','as','dos','como','mas','ao','ele','das','à','seu','sua','ou','quando','muito','nos','já','eu','também','só','pelo','pela','até','isso','ela','entre','depois','sem','mesmo','aos','seus','quem','nas','me','esse','eles','você','essa','num','nem','suas','meu','às','minha','numa','pelos','elas','qual','nós','lhe','deles','essas','esses','pelas','este','dele','tu','te','vocês','vos','lhes','meus','minhas','teu','tua','teus','tuas','nosso','nossa','nossos','nossas','dela','delas','esta','estes','estas','aquele','aquela','aqueles','aquelas','isto','aquilo','estou','está','estamos','estão','estive','esteve','estivemos','estiveram','estava','estávamos','estavam','estivera','estivéramos','esteja','estejamos','estejam','estivesse','estivéssemos','estivessem','estiver','estivermos','estiverem','hei','há','havemos','hão','houve','houvemos','houveram','houvera','houvéramos','haja','hajamos','hajam','houvesse','houvéssemos','houvessem','houver','houvermos','houverem','houverei','houverá','houveremos','houverão','houveria','houveríamos','houveriam','sou','somos','são','era','éramos','eram','fui','foi','fomos','foram','fora','fôramos','seja','sejamos','sejam','fosse','fôssemos','fossem','for','formos','forem','serei','será','seremos','serão','seria','seríamos','seriam','tenho','tem','temos','tém','tinha','tínhamos','tinham','tive','teve','tivemos','tiveram','tivera','tivéramos','tenha','tenhamos','tenham','tivesse','tivéssemos',
'tivessem','tiver','tivermos','tiverem','terei','terá','teremos','terão','teria','teríamos','teriam'])
symbols = set(['-', 'r$', 'R$', '.'])

# Doria
# separando as palavras
palavras = "".join(politicos['Doria']['text']).lower().split()
# returando stopwords e depois os web links
palavras = [w for w in palavras if not w in (stop_words | symbols)]
palavras = [w for w in palavras if re.match(r'https://*', w) == None]

c = Counter(palavras)
# retirando palavras com frequencia menor do que 5 e adicionando numro ao candidato
dados = {(1,x,y) for x,y in zip(c,c.values()) if y > 5}
print("Doria", len(dados))

# Bolsonaro
palavras = "".join(politicos['Bolsonaro']['text']).lower().split()
palavras = [w for w in palavras if not w in (stop_words | symbols)]
palavras = [w for w in palavras if re.match(r'https://*', w) == None]

c = Counter(palavras)
d = {(2,x,y) for x,y in zip(c,c.values()) if y > 5}
print("Bolsonaro", len(d))
# adicionando aos dados
for x in d:
    dados.add(x)

# Lula
palavras = "".join(politicos['Lula']['text']).lower().split()
palavras = [w for w in palavras if not w in (stop_words | symbols)]
palavras = [w for w in palavras if re.match(r'https://*', w) == None]

c = Counter(palavras)
d = {(3,x,y) for x,y in zip(c,c.values()) if y > 5}
print("Lula", len(d))
for x in d:
    dados.add(x)

print("Total", len(dados))

# montando o dataframe
df = pd.DataFrame(dados, columns=['candidato', 'texto', 'frequencia'])
df.sort_values('frequencia', ascending=False)
# Out:
# Doria 1559
# Bolsonaro 1475
# Lula 1633
# Total 4667
#       candidato          texto  frequencia
# 3128          3           lula         602
# 2813          1             sp         452
# 3935          1        governo         445
# 1459          1        vacinar         435
# 2522          1            vou         418
# ...         ...            ...         ...
# 1675          2     juntamente           6
# 3830          3          acima           6
# 1665          2  🤝@tarcisiogdf           6
# 3834          2       indígena           6
# 4666          2             pe           6
#
# [4667 rows x 3 columns]

# %% [markdown]
# ## WordCloud de todos

# %%
palavras = []
fig, ax = plt.subplots(nrows=6, ncols=2, figsize=(20, 60), facecolor='k')
xc = 0
yc = 0
for idx in range(11):
    palavras.append("".join(politicos[nome_politicos[idx]]['text']).lower().split())
    palavras[idx] = [w for w in palavras[idx] if not w in (stop_words | symbols)]
    palavras[idx] = [w for w in palavras[idx] if re.match(r'https://*', w) == None]
    sumario = " ".join(s for s in palavras[idx])
    wordcloud = WordCloud(width=800, height=800, max_words = 50).generate(sumario)
    ax[xc][yc].imshow(wordcloud)
    ax[xc][yc].text(50, -10, nome_politicos[idx], fontsize=28, color='white')
    yc += 1
    if (yc == 2):
        yc = 0
        xc += 1
        if (xc == 6):
            xc = 0

plt.axis('off')
plt.tight_layout(pad=0) 
plt.show()

# %% [markdown]
# Criando conjunto de palavras únicas com as palavras de todos os políticos

# %%
palavras_unicas = set()
numero_total_palavras = 0
for c in palavras:
    for p in c:
        palavras_unicas.add(p)
        numero_total_palavras += 1
print(numero_total_palavras, len(palavras_unicas))
# Out:
# 508217 85146

# %% [markdown]
# ## LDA - Latent Dirichlet Allocation - Modelagem de Tópicos

# %%
# Function to remove emoji.
def emoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
def print_top_words(model, feature_names, n_top_words):
    for index, topic in enumerate(model.components_):
        message = "\nTopic #{}:".format(index)
        message += " ".join([feature_names[i] for i in topic.argsort()[:-n_top_words - 1 :-1]])
        print(message)
        print("="*70)

# %%
# stopwords e simbolos a retirar
stop_words = set(stopwords.words('portuguese'))
symbols = set(['-', 'r$', 'R$'])

for idx in range(len(nome_politicos)):
    politicos[nome_politicos[idx]]['tweet_token'] = 'NaN'
    tweets = politicos[nome_politicos[idx]]['text']
    for index, row in politicos[nome_politicos[idx]].iterrows():
        tweet = row['text'].lower()
        tweet_token = [w for w in tweet.split() if not w in (stop_words | symbols)]
        tweet_token = [w for w in tweet_token if re.match(r'http*', w) == None]
        tweet_token = [w for w in tweet_token if not w.startswith('@')]
        tweet_token = [w for w in tweet_token if not w.startswith('#')]
        tweet_token = [w for w in tweet_token if w != 'rt']

        politicos[nome_politicos[idx]].loc[index, 'tweet_token'] = emoji(" ".join(tweet_token))

# %%
tweets = list()
for politico in nome_politicos:
    tweets.extend(list(politicos[politico]['tweet_token']))

tf_vectorizer = CountVectorizer()
tf = tf_vectorizer.fit_transform(tweets)

lda = LatentDirichletAllocation(n_components=11, max_iter=5,
                                learning_method = 'online',
                                learning_offset = 50.,
                                random_state = 0)
lda.fit(tf)

n_top_words = 3
print("\nTópico no Modelo LDA: ")
print("*"*70)
tf_feature_names = tf_vectorizer.get_feature_names()
print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Tópico no Modelo LDA:
# **********************************************************************
#
# Topic #0:co importante redes
# ======================================================================
#
# Topic #1:co brasil presidente
# ======================================================================
#
# Topic #2:co lulaoficial la
# ======================================================================
#
# Topic #3:operação tv drogas
# ======================================================================
#
# Topic #4:estado medidas educação
# ======================================================================
#
# Topic #5:co saúde milhões
# ======================================================================
#
# Topic #6:vacina co tudo
# ======================================================================
#
# Topic #7:co rio ambiente
# ======================================================================
#
# Topic #8:co hoje paulo
# ======================================================================
#
# Topic #9:co jairbolsonaro empresas
# ======================================================================
#
# Topic #10:co vamosriogrande borafazerrs
# ======================================================================

# %% [markdown]
# ## LDA - Latent Dirichlet Allocation - Modelagem de Tópicos Politicos

# %%
tf_vectorizer = CountVectorizer()
for politico in nome_politicos:
    tf = tf_vectorizer.fit_transform((list(politicos[politico]['tweet_token'])))
    lda = LatentDirichletAllocation(n_components=11, max_iter=5,
                                    learning_method = 'online',
                                    learning_offset = 50.,
                                    random_state = 0)
    lda.fit(tf)

    n_top_words = 3
    print(f"\nTópico no Modelo LDA: {politico}")
    print("*"*70)
    tf_feature_names = tf_vectorizer.get_feature_names()
    print_top_words(lda, tf_feature_names, n_top_words)
# Out:
# Tópico no Modelo LDA: Amoedo
# **********************************************************************
#
# Topic #0:co impeachment bolsonaro
# ======================================================================
#
# Topic #1:smith adam filósofo
# ======================================================================
#
# Topic #2:legal colabora coletar
# ======================================================================
#
# Topic #3:exato escolha qualificado
# ======================================================================
#
# Topic #4:co episódio novocast
# ======================================================================
#
# Topic #5:co conta informações
# ======================================================================
#
# Topic #6:fonte co casa
# ======================================================================
#
# Topic #7:co novo brasil
# ======================================================================
#
# Topic #8:feira debate jornal
# ======================================================================
#
# Topic #9:liberdade reforma estado
# ======================================================================
#
# Topic #10:setor privado sistema
# ======================================================================
#
# Tópico no Modelo LDA: Bolsonaro
# **********************************************************************
#
# Topic #0:eleições conexaopolitica liberdades
# ======================================================================
#
# Topic #1:al ernestofaraujo disso
# ======================================================================
#
# Topic #2:arthurweint damaresalves ouvindo
# ======================================================================
#
# Topic #3:br dnitoficial tarcisiogdf
# ======================================================================
#
# Topic #4:prfbrasil cocaína apreensão
# ======================================================================
#
# Topic #5:ceagesp cel mello
# ======================================================================
#
# Topic #6:co brasil milhões
# ======================================================================
#
# Topic #7:co youtube link
# ======================================================================
#
# Topic #8:co govbr covid
# ======================================================================
#
# Topic #9:caos povo moro
# ======================================================================
#
# Topic #10:embaixadas dano jornalista
# ======================================================================
#
# Tópico no Modelo LDA: Boulos
# **********************************************************************
#
# Topic #0:aulas professor volta
# ======================================================================
#
# Topic #1:2020 sp pesquisa
# ======================================================================
#
# Topic #2:co pra virasp50
# ======================================================================
#
# Topic #3:auxílio emergencial co
# ======================================================================
#
# Topic #4:mortos brasil genocida
# ======================================================================
#
# Topic #5:bolsonaro brasil co
# ======================================================================
#
# Topic #6:chico ferreira leandro
# ======================================================================
#
# Topic #7:obrigado belém juntos
# ======================================================================
#
# Topic #8:racismo mudou feminicídio
# ======================================================================
#
# Topic #9:co ônibus en
# ======================================================================
#
# Topic #10:produção to composição
# ======================================================================
#
# Tópico no Modelo LDA: Ciro
# **********************************************************************
#
# Topic #0:guilherme_amado ciroamado co
# ======================================================================
#
# Topic #1:antonionetopdt lucianagenro naradepaula5
# ======================================================================
#
# Topic #2:co pdt carloslupipdt
# ======================================================================
#
# Topic #3:co acompanhe começou
# ======================================================================
#
# Topic #4:boa vamos turma
# ======================================================================
#
# Topic #5:julianabrizola feliz porto
# ======================================================================
#
# Topic #6:alessandromolon bolsonaro pessoas
# ======================================================================
#
# Topic #7:cironootimista ootimistajornal projectnacional
# ======================================================================
#
# Topic #8:equipecirogomes co banco
# ======================================================================
#
# Topic #9:co bolsonaro brasil
# ======================================================================
#
# Topic #10:bora youtube canal
# ======================================================================
#
# Tópico no Modelo LDA: Doria
# **********************************************************************
#
# Topic #0:sindicato peixe indústria
# ======================================================================
#
# Topic #1:democracia direito bolsonaro
# ======================================================================
#
# Topic #2:farmácias álcool gel
# ======================================================================
#
# Topic #3:vacinar vou obrigado
# ======================================================================
#
# Topic #4:kits qualquer ser
# ======================================================================
#
# Topic #5:news fake informação
# ======================================================================
#
# Topic #6:co sp governosp
# ======================================================================
#
# Topic #7:arrecadação fórmula gp
# ======================================================================
#
# Topic #8:polícia vida vitória
# ======================================================================
#
# Topic #9:funcionamento albert einstein
# ======================================================================
#
# Topic #10:co vacina vidas
# ======================================================================
#
# Tópico no Modelo LDA: Huck
# **********************************************************************
#
# Topic #0:co valeu caldeirão
# ======================================================================
#
# Topic #1:to co the
# ======================================================================
#
# Topic #2:co dandovalor brasil
# ======================================================================
#
# Topic #3:co caldeirão hj
# ======================================================================
#
# Topic #4:rio co fã
# ======================================================================
#
# Topic #5:co foto acabou
# ======================================================================
#
# Topic #6:salve elenco pronto
# ======================================================================
#
# Topic #7:vapabuçu risada pontos
# ======================================================================
#
# Topic #8:co nasa kkkkkkk
# ======================================================================
#
# Topic #9:equipe educação ferramenta
# ======================================================================
#
# Topic #10:co vivo live
# ======================================================================
#
# Tópico no Modelo LDA: Leite
# **********************************************************************
#
# Topic #0:co globonews eduardoleite_
# ======================================================================
#
# Topic #1:educação aulas ensino
# ======================================================================
#
# Topic #2:família confronto deixe
# ======================================================================
#
# Topic #3:piratini palácio rosaneoliveira
# ======================================================================
#
# Topic #4:compras família limite
# ======================================================================
#
# Topic #5:fakenewsnão news rbstv
# ======================================================================
#
# Topic #6:co vamosriogrande borafazerrs
# ======================================================================
#
# Topic #7:direito aí greve
# ======================================================================
#
# Topic #8:co rs estado
# ======================================================================
#
# Topic #9:valorização museu mérito
# ======================================================================
#
# Topic #10:leitos uti sus
# ======================================================================
#
# Tópico no Modelo LDA: Lula
# **********************************************************************
#
# Topic #0:le est des
# ======================================================================
#
# Topic #1:co lula brasil
# ======================================================================
#
# Topic #2:jato lava conversas
# ======================================================================
#
# Topic #3:trocar guajajara atacado
# ======================================================================
#
# Topic #4:quebra h1n1 todas
# ======================================================================
#
# Topic #5:ajuda acidente profissionais
# ======================================================================
#
# Topic #6:co lula equipelula
# ======================================================================
#
# Topic #7:vencerá verdade fortalecer
# ======================================================================
#
# Topic #8:recomendo reação netflixbrasil
# ======================================================================
#
# Topic #9:la co en
# ======================================================================
#
# Topic #10:co lulaoficial ricardo
# ======================================================================
#
# Tópico no Modelo LDA: Mandetta
# **********************************************************************
#
# Topic #0:co saúde minsaude
# ======================================================================
#
# Topic #1:cunha cassação eduardo
# ======================================================================
#
# Topic #2:respeito ciência democratas
# ======================================================================
#
# Topic #3:co jairbolsonaro obrigado
# ======================================================================
#
# Topic #4:helenclarknz pt to
# ======================================================================
#
# Topic #5:azevedokelvia hospitais risco
# ======================================================================
#
# Topic #6:co lucyborn23 democratas
# ======================================================================
#
# Topic #7:parabéns vida onde
# ======================================================================
#
# Topic #8:my mandetta sounds
# ======================================================================
#
# Topic #9:santanasince79 staut_brito nenagv
# ======================================================================
#
# Topic #10:mandetta co democratas
# ======================================================================
#
# Tópico no Modelo LDA: Marina
# **********************************************************************
#
# Topic #0:querendo tome torcida
# ======================================================================
#
# Topic #1:silêncio aprendem to
# ======================================================================
#
# Topic #2:saído mpdagrilagem toma
# ======================================================================
#
# Topic #3:ranking demonstram pequenas
# ======================================================================
#
# Topic #4:co hoje marinasilva
# ======================================================================
#
# Topic #5:co governo presidente
# ======================================================================
#
# Topic #6:recebi falecimento notícia
# ======================================================================
#
# Topic #7:sintomas instituto criador
# ======================================================================
#
# Topic #8:barroso comunidades cumprimento
# ======================================================================
#
# Topic #9:21 vida básico
# ======================================================================
#
# Topic #10:dia co hoje
# ======================================================================
#
# Tópico no Modelo LDA: Moro
# **********************************************************************
#
# Topic #0:cadastro época trf4
# ======================================================================
#
# Topic #1:supostas mensagens obtidas
# ======================================================================
#
# Topic #2:eleição simbólico acontecer
# ======================================================================
#
# Topic #3:priweinstein radicais americana
# ======================================================================
#
# Topic #4:co solidariedade fake
# ======================================================================
#
# Topic #5:presos co preso
# ======================================================================
#
# Topic #6:vacina tolerância 19
# ======================================================================
#
# Topic #7:verdade lhmandetta propaganda
# ======================================================================
#
# Topic #8:co dia presos
# ======================================================================
#
# Topic #9:co brasil federal
# ======================================================================
#
# Topic #10:co mjsp segurança
# ======================================================================
